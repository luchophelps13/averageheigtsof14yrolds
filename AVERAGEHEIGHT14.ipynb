# %% [markdown]
# #Graphing the Heights of 14-year-olds

# %%
import matplotlib.pyplot as plt
import numpy as np

boys_mu, girls_sigma = 67, 2

girls_mu, girls_sigma = 64, 2

boys = boys_mu + girls_sigma * np.random.randn(25000000)

girls = girls_mu + girls_sigmna * np.random.randn(25000000)

n, bins, patches = plt.hist(boys, 50, density=1, facecolor = 'b', alpha=.75)

n, bins, patches = plt.hist(girls, 50, density=1, facecolor = 'r', alpha=.75)

plt.xlabel('Height in Inches')
plt.ylabel('Probability')
plt.title('Average Height for 14-year-olds')
plt.text(67.5, .025, r'$\mu=66.6 in,\ \sigma=1.5 in$')
plt.text(60, .025, r'$\mu=64 in,\ \sigma=1.5 in$')
plt.axis([56, 75, 0, 0.225])
plt.grid(True)
plt.legend(['boys', 'girls'])
plt.show()
